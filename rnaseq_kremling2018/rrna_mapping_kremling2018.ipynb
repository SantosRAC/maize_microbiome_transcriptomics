# %%
#pip install pandas
#pip install matplotlib
import pandas as pd

# %%
# Read the file and create a dataframe
df = pd.read_csv('rrna_kremling2018_alignment_percent.txt', header=None, names=['percent_alignment'])

# Generate a boxplot
df.boxplot(column='percent_alignment')
# Out:
# <Axes: >
