# %%
import pandas as pd

# %%
kremling_expression_v5_tpm_filtered_cv_filtered = pd.read_csv("/home/rsantos/Repositories/maize_microbiome_transcriptomics/poster_presentation_notebooks/plant_center_retreat_2024/kremling_expression_v5_tpm_filtered_cv_filtered.tsv",
                                                        sep="\t")
kremling_expression_v5_tpm_filtered_cv_filtered.set_index('Name', inplace=True)

summed_otu_separate_day_night_cpm_filtered_cv_filtered = pd.read_csv("/home/rsantos/Repositories/maize_microbiome_transcriptomics/poster_presentation_notebooks/plant_center_retreat_2024/summed_otu_separate_day_night_cpm_filtered_cv_filtered.tsv",
                                                        sep="\t")
summed_otu_separate_day_night_cpm_filtered_cv_filtered.set_index('OTU_ID', inplace=True)

# %%
row_gene = kremling_expression_v5_tpm_filtered_cv_filtered.loc['Zm00001eb036130_T001'].to_list() # peptidyl-prolyl cis-trans isomerase activity
row_otu = summed_otu_separate_day_night_cpm_filtered_cv_filtered.loc['New.ReferenceOTU2397'].to_list() # Deinococcus species

# %%
import matplotlib.pyplot as plt

plt.scatter(row_gene[:176], row_otu[:176], color='blue')
plt.xlabel('Zm00001eb036130_T')
plt.ylabel('New.ReferenceOTU2397')
plt.title('Gene (TPM) x OTU (CPM) for Day')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(row_gene[177:], row_otu[177:], color='red')
plt.xlabel('Zm00001eb036130_T')
plt.ylabel('New.ReferenceOTU2397')
plt.title('Gene (TPM) x OTU (CPM) for Night')
plt.show()
