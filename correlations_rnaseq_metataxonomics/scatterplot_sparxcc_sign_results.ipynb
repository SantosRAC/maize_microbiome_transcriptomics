# %%
import pandas as pd

# %% [markdown]
# # Counts

# %%
expression_data = pd.read_csv("/home/rsantos/Repositories/maize_microbiome_transcriptomics/rnaseq_kremling2018/quantification/kremling_expression_v5_day_counts_filtered_cv_filtered.tsv",
                             sep='\t')
expression_data.set_index('Name', inplace=True)
otu_data = pd.read_csv("/home/rsantos/Repositories/maize_microbiome_transcriptomics/16S_wallace2018/combine_day_night_samples/otu_table_merged_counts_day_filtered_cv_filtered.tsv",
                             sep='\t')
otu_data.set_index('OTU ID', inplace=True)

# %%
concat_df = pd.concat([expression_data, otu_data])

# %%
concat_transposed = concat_df.T

# %%
concat_transposed.plot.scatter(x='Zm00001eb168100_T001', y='561885')
# Out:
# <Axes: xlabel='Zm00001eb168100_T001', ylabel='561885'>

# %% [markdown]
# # CPM

# %%
expression_data_cpm = pd.read_csv("/home/rsantos/Repositories/maize_microbiome_transcriptomics/rnaseq_kremling2018/quantification/kremling_expression_v5_day_cpm_filtered_cv_filtered.tsv",
                             sep='\t')
expression_data_cpm.set_index('Name', inplace=True)
otu_data_cpm = pd.read_csv("/home/rsantos/Repositories/maize_microbiome_transcriptomics/16S_wallace2018/combine_day_night_samples/otu_table_merged_day_cpm_filtered_cv_filtered.tsv",
                             sep='\t')
otu_data_cpm.set_index('OTU ID', inplace=True)

# %%
concat_df = pd.concat([expression_data_cpm, otu_data_cpm])
concat_transposed = concat_df.T

# %%
concat_transposed.plot.scatter(x='Zm00001eb314260_T001', y='444896')
# Out:
# <Axes: xlabel='Zm00001eb314260_T001', ylabel='444896'>

# %%
genus_data_cpm = pd.read_csv("/home/rsantos/Repositories/maize_microbiome_transcriptomics/16S_wallace2018/combine_day_night_samples/genus_table_merged_d_n_day_cpm.tsv",
                             sep='\t')
genus_data_cpm.set_index('Genus', inplace=True)

# %%
concat_df = pd.concat([expression_data_cpm, genus_data_cpm])
concat_transposed = concat_df.T

# %%
concat_transposed.plot.scatter(x='Zm00001eb032800_T001', y='Thermobifida')
# Out:
# <Axes: xlabel='Zm00001eb032800_T001', ylabel='Thermobifida'>
