# %% [markdown]
# # Summary of Dada2 stats
#
#  * Denoise-single - forward reads, min quality 20 and min length 50
#  * Denoise-single - forward reads, min quality 20 and min length 150

# %%
import pandas as pd

# Read the TSV file into a pandas DataFrame
q20_min50bp_fw_dada2_stats_df = pd.read_csv('/media/renato/SSD1TB/Repositories/maize_microbiome_transcriptomics/16S_wallace2018/dada2_stats/q20_min50bp_fw_dada2denoisesingle_stats.tsv',
                 sep='\t', comment='#')
q20_min150bp_fw_dada2_stats_df = pd.read_csv('/media/renato/SSD1TB/Repositories/maize_microbiome_transcriptomics/16S_wallace2018/dada2_stats/q20_min150bp_fw_dada2denoisesingle_stats.tsv',
                 sep='\t', comment='#')

# Display the DataFrame
print(q20_min50bp_fw_dada2_stats_df.head())
print(q20_min150bp_fw_dada2_stats_df.head())
# Out:
#     sample-id   input  filtered  percentage of input passed filter  denoised  \
# 0  SRR6665476   77710     49516                              63.72     49515
# 1  SRR6665477   28401     26650                              93.83     26468
# 2  SRR6665478  214427    202194                              94.30    202069
# 3  SRR6665479  362170    338427                              93.44    338160
# 4  SRR6665480  271248    257276                              94.85    256954
#
#    non-chimeric  percentage of input non-chimeric
# 0         49515                             63.72
# 1         20458                             72.03
# 2        139510                             65.06
# 3        255619                             70.58
# 4        193849                             71.47
#     sample-id   input  filtered  percentage of input passed filter  denoised  \
# 0  SRR6665476   71673     45893                              64.03     45892
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a pandas Series called 'data'
q20_min50bp_fw_dada2_stats_df['input'].plot.box()

# Set the title and labels
plt.title('Boxplot')
plt.xlabel('Series')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a pandas Series called 'data'
q20_min50bp_fw_dada2_stats_df['percentage of input non-chimeric'].plot.box()

# Set the title and labels
plt.title('Boxplot')
plt.xlabel('Series')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a pandas Series called 'data'
q20_min150bp_fw_dada2_stats_df['input'].plot.box()

# Set the title and labels
plt.title('Boxplot')
plt.xlabel('Series')
plt.ylabel('Values')

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a pandas Series called 'data'
q20_min150bp_fw_dada2_stats_df['percentage of input non-chimeric'].plot.box()

# Set the title and labels
plt.title('Boxplot')
plt.xlabel('Series')
plt.ylabel('Values')

# Show the plot
plt.show()
