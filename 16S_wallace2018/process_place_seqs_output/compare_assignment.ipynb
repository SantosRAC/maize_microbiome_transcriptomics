# %% [markdown]
# # Comparing the output of placement and assignment of taxonomy of FW and RV reads

# %%
import pandas as pd

# Read the table from a file
q20_fw_df = pd.read_table('/media/rsantos/4TB_drive/Projects/UGA_RACS/16S/Qiime2/dada2/as_single_q20/q20_fw_feature-table_placement_taxonomy.tsv')

# Display the table
q20_fw_df.shape
# Out:
# (6241, 594)

# %%
import pandas as pd

# Read the table from a file
q20_rv_df = pd.read_table('/media/rsantos/4TB_drive/Projects/UGA_RACS/16S/Qiime2/dada2/as_single_q20/q20_rv_feature-table_placement_taxonomy.tsv')

# Display the table
q20_rv_df.shape
# Out:
# (5374, 594)

# %%
q20_rv_df.iloc[:, 2:].sum(axis=1).sort_values(ascending=False).head(n=30)
# Out:
# 0     48544430.0
# 1      4743954.0
# 2      3333312.0
# 3      3190442.0
# 4      2151661.0
# 5      1779790.0
# 6      1520777.0
# 7      1457057.0
# 8      1253476.0
# 9      1184459.0
# 10      929200.0
# 11      919602.0
# 12      887546.0
# 13      655382.0
# 14      648221.0
# 15      648027.0
# 16      616453.0
# 17      520086.0
# 18      493251.0
# 19      455517.0
# 20      333969.0
# 21      332125.0
# 22      310810.0
# 23      299740.0
# 24      284179.0
# 25      270696.0
# 26      237768.0
# 27      236823.0
# 28      233097.0
# 29      231876.0
# dtype: float64

# %%
q20_rv_df.iloc[q20_rv_df.iloc[:, 2:].sum(axis=1).sort_values(ascending=False).head(n=30).index][['Taxon', 'SRR6665526','SRR6665527','SRR6665528', 'SRR6665529', 'SRR6665530']]
# Out:
#                                                 Taxon  SRR6665526  SRR6665527  \
# 0                                            unplaced         0.0         0.0
# 1         Bacteria;Pseudomonadota;Alphaproteobacteria      4492.0      1614.0
# 2         Bacteria;Pseudomonadota;Alphaproteobacteria      2937.0      1076.0
# 3         Bacteria;Pseudomonadota;Alphaproteobacteria      2985.0      1096.0
# 4   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...       488.0      1406.0
# 5         Bacteria;Pseudomonadota;Alphaproteobacteria      6548.0       159.0
# 6   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...       292.0      1066.0
# 7   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...       277.0       933.0
# 8         Bacteria;Pseudomonadota;Alphaproteobacteria      4249.0       114.0
# 9         Bacteria;Pseudomonadota;Alphaproteobacteria      4128.0        96.0
# 10  Bacteria;Actinomycetota;Actinomycetes;Micrococ...      1926.0       248.0
# ...

# %%
q20_fw_df.iloc[q20_fw_df.iloc[:, 2:].sum(axis=1).sort_values(ascending=False).head(n=30).index][['Taxon', 'SRR6665526','SRR6665527','SRR6665528', 'SRR6665529', 'SRR6665530']]
# Out:
#                                                 Taxon  SRR6665526  SRR6665527  \
# 0                                            unplaced     31471.0     10851.0
# 1   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 2   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 3   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 4   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 5   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 6   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 7   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 8   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 9   Bacteria;Pseudomonadota;Alphaproteobacteria;Sp...         0.0         0.0
# 10  Bacteria;Pseudomonadota;Alphaproteobacteria;Hy...         0.0         0.0
# ...

# %%
q20_fw_df.drop('ASV', axis=1).groupby(['Taxon']).sum()
# Out:
#                                                     SRR6665476  SRR6665477  \
# Taxon
# Archaea                                                    0.0        66.0
# Archaea;Candidatus Thermoplasmatota;Thermoplasm...         0.0         0.0
# Archaea;Nitrososphaerota                                   0.0         0.0
# Bacteria                                                   0.0      1115.0
# Bacteria;Acidobacteriota;Terriglobia;Bryobacter...         0.0         0.0
# ...                                                        ...         ...
# Bacteria;Verrucomicrobiota                                 0.0         0.0
# Bacteria;Verrucomicrobiota;Verrucomicrobiae;Lim...         0.0         0.0
# Bacteria;unclassified;Deltaproteobacteria;uncla...         0.0         0.0
# Bacteria;unclassified;unclassified;unclassified...         0.0         0.0
# unplaced                                               49515.0         0.0
#
# ...

# %%
q20_rv_df.drop('ASV', axis=1).groupby(['Taxon']).sum()
# Out:
#                                                     SRR6665476  SRR6665477  \
# Taxon
# Archaea;Candidatus Thermoplasmatota;Thermoplasm...         0.0         0.0
# Archaea;Euryarchaeota;Halobacteria;Halobacteria...         0.0         0.0
# Archaea;Euryarchaeota;Halobacteria;Haloferacale...         0.0         0.0
# Bacteria                                                  18.0         0.0
# Bacteria;Acidobacteriota;Terriglobia;Bryobacter...         0.0         0.0
# ...                                                        ...         ...
# Bacteria;Verrucomicrobiota;Verrucomicrobiae;Lim...         0.0         0.0
# Bacteria;Verrucomicrobiota;unclassified;unclass...         0.0         0.0
# Bacteria;unclassified;Deltaproteobacteria;uncla...         0.0         0.0
# Bacteria;unclassified;unclassified;unclassified...         0.0         0.0
# unplaced                                                  29.0     18206.0
#
# ...

# %%
q20_rv_df.drop('ASV', axis=1).groupby(['Taxon']).sum().sum(axis=1).sort_values(ascending=False).head(n=20)
# Out:
# Taxon
# unplaced                                                                               50340278.0
# Bacteria;Pseudomonadota;Alphaproteobacteria                                            15950944.0
# Bacteria;Pseudomonadota;Alphaproteobacteria;Sphingomonadales;Sphingomonadaceae          5484086.0
# Bacteria;Pseudomonadota;Alphaproteobacteria;Hyphomicrobiales;Methylobacteriaceae        3900017.0
# Bacteria;Pseudomonadota;Gammaproteobacteria;Enterobacterales;Enterobacteriaceae         2415323.0
# Bacteria;Actinomycetota;Actinomycetes;Micrococcales;Microbacteriaceae                   1155916.0
# Bacteria;Pseudomonadota;Betaproteobacteria;Burkholderiales;Comamonadaceae                992408.0
# Bacteria;Pseudomonadota;Alphaproteobacteria;Hyphomicrobiales                             877196.0
# Bacteria;Bacteroidota;Cytophagia;Cytophagales;Hymenobacteraceae                          845912.0
# ...

# %%
q20_fw_df.drop('ASV', axis=1).groupby(['Taxon']).sum().sum(axis=1).sort_values(ascending=False).head(n=20)
# Out:
# Taxon
# unplaced                                                                            33958700.0
# Bacteria;Pseudomonadota;Alphaproteobacteria;Sphingomonadales;Sphingomonadaceae      30924546.0
# Bacteria;Pseudomonadota;Alphaproteobacteria;Hyphomicrobiales;Methylobacteriaceae     9582508.0
# Bacteria;Bacteroidota;Cytophagia;Cytophagales;Hymenobacteraceae                      3095947.0
# Bacteria                                                                             1908564.0
# Bacteria;Pseudomonadota;Gammaproteobacteria;Enterobacterales;Enterobacteriaceae      1732445.0
# Bacteria;Bacteroidota;Flavobacteriia;Flavobacteriales                                1101106.0
# Bacteria;Pseudomonadota;Alphaproteobacteria;Hyphomicrobiales                          818330.0
# Bacteria;Pseudomonadota;Betaproteobacteria;Burkholderiales;Comamonadaceae             696966.0
# Bacteria;Pseudomonadota                                                               533583.0
# ...
